# %% [markdown]
# # Librería YData Profiling permite crear informes de AED con visualizaciones, estadística descriptivas, análisis de  correlacción y detección de valores atípicos

# %%
#===================================
#1. SUBIR ARCHIVOS A COLAB
#https://www.google.com/url?sa=D&q=https://datosabiertos.jcyl.es/web/jcyl/risp/es/medio-ambiente/calidad_aire_historico/1284212629698.csv&ust=1763851980000000&usg=AOvVaw10Akccml2IFgfgcwu0X-Kl&hl=es
#El Archivo descargado se encuentra en ./Datos/CALIDAD-DEL-AIRE-DATOS-HISTORICOS-DIARIOS-1997a2022.csv
#Validar si este libro es el mismo que "06_TitanicInformesInteractivosAED.ipynb"
#=====================================
from google.colab import files
import pandas as pd
uploaded =files.upload()
file_name=list(uploaded.keys())[0]
print("Aechivo cargado:",file_name)
df=pd.read_csv(file_name,sep=';')
df.head()
# Out:
#      <input type="file" id="files-f5f24736-08c2-4de9-995f-1f07f1890bcb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5f24736-08c2-4de9-995f-1f07f1890bcb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Instalación de las variables necesarias
# !pip install -q --upgrade ydata-profiling
# !pip install -q ipwidgets
#activar ipwidgets en colab
from google.colab import output
output.enable_custom_widget_manager()
#generar reporte automático
from ydata_profiling import ProfileReport
#report = ProfileReport(df, title="Reporte de Análisis Exploratorio de Datos")
report = ProfileReport(df.sample(50000), title="Reporte de Análisis Exploratorio de Datos")
#guardar el reporte
report_file= 'reporte_calidad_aire.html'
report.to_file(report_file)
report_file
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.7/398.7 kB 27.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.1 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement ipwidgets (from versions: none)
# ERROR: No matching distribution found for ipwidgets
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# 'reporte_calidad_aire.html'
