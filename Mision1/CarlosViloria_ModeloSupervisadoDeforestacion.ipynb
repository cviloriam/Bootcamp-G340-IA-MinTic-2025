# %% [markdown]
# # 🌱 Análisis Supervisado de Deforestación - Departamento del Chocó
#
#
# Proyecto educativo de inteligencia artificial ambiental
#
#
# Enfoque: Aprendizaje supervisado con Randow Forest
#
# Este cuaderno ilustra cómo aplicar un modelo supervisado para predecir si  un área presenta alta o baja deforestación, utilizando datos geográficos t temporales del Chocó
# link:https://www.datos.gov.co/Ambiente-y-Desarrollo-Sostenible/AREAS-DEFORESTADAS-CHOCO/iczg-dyt3/about

# %%
#Cargar Mi Unidad de G.Drive
from google.colab import drive
drive.mount('/content/drive')
print('Unidad G.Drive Cargada: OK')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Unidad G.Drive Cargada: OK

# %%
#Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print('Importar Librerías Necesarias: OK')
# Out:
# Importar Librerías Necesarias: OK

# %%
#Cargar datos
df = pd.read_csv("/content/drive/MyDrive/2.Docs/07. Learning.Study/MinTic/Talento Tech/Bootcamp G340 IA MinTic 2025/PRY-G340-IA/Mision1/AREAS_DEFORESTADAS_CHOCO_20251117.csv")
print('Dimensiones del Dataset:',df.shape)
df.head()
# Out:
# Dimensiones del Dataset: (7937, 10)
#      ID TIPO GEOMETRIA    AÑO  \
# 0  7463        Polygon  2,020
# 1  4659        Polygon  2,019
# 2  7459        Polygon  2,020
# 3  9719        Polygon  2,021
# 4  7464        Polygon  2,020
#
#                                               IMAGEN    CAUSA   AREA_Ha  \
# 0  T18PTQ_20200201T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.126512
# 1  T18PTQ_20190527T153621_TCI_10m.jp2 - T18PTQ_20...  Cultivo   0.14072
# 2  T18PTQ_20200112T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo   0.14125
# 3  T18PTQ_20201202T153619_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.158066
# 4  T18PTQ_20200201T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.184549
#
#   OBSERVACION           LATITUD           LONGITUD MUNICIPIO
# 0     Ninguna  8° 22' 43,726" N  77° 14' 19,019" W    ACANDÍ
# 1     Ninguna  8° 30' 47,551" N  77° 19' 30,507" W    ACANDÍ
# 2     Ninguna  8° 22' 30,966" N  77° 13' 49,720" W    ACANDÍ
# 3     Ninguna  8° 36' 11.256" N  77° 20' 50.757" W    ACANDÍ
# 4     Ninguna  8° 22' 22,008" N   77° 14' 3,921" W    ACANDÍ

# %%
#Tipos de datos de cada columna
df.dtypes
# Out:
# ID                 int64
# TIPO GEOMETRIA    object
# AÑO               object
# IMAGEN            object
# CAUSA             object
# AREA_Ha           object
# OBSERVACION       object
# LATITUD           object
# LONGITUD          object
# MUNICIPIO         object
# dtype: object

# %%
#Resumen más completo
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7937 entries, 0 to 7936
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              7937 non-null   int64
#  1   TIPO GEOMETRIA  7937 non-null   object
#  2   AÑO             7937 non-null   object
#  3   IMAGEN          5901 non-null   object
#  4   CAUSA           7718 non-null   object
#  5   AREA_Ha         7937 non-null   object
#  6   OBSERVACION     7937 non-null   object
#  7   LATITUD         7930 non-null   object
#  8   LONGITUD        7930 non-null   object
#  9   MUNICIPIO       7937 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 620.2+ KB

# %%
#Contar columnas categóricas, normalmente son tipo object o category
cat_cols =df.select_dtypes(include=['object','category']).columns
num_cat = len(cat_cols)
print("Columnas Categóricas:", num_cat)
print("Nombre:",list(cat_cols))
# Out:
# Columnas Categóricas: 9
# Nombre: ['TIPO GEOMETRIA', 'AÑO', 'IMAGEN', 'CAUSA', 'AREA_Ha', 'OBSERVACION', 'LATITUD', 'LONGITUD', 'MUNICIPIO']

# %%
#Columnas neméricas int64 o float64
cont_cols=df.select_dtypes(include=['int64','float64']).columns
num_cont=len(cont_cols)
print("Columnas Númericas:", num_cont)
print("Nombre:",list(cont_cols))
# Out:
# Columnas númericas: 1
# Nombre: ['ID']

# %%
#Total de valores nulos por columna
print(df.isnull().sum())
# Out:
# ID                   0
# TIPO GEOMETRIA       0
# AÑO                  0
# IMAGEN            2036
# CAUSA              219
# AREA_Ha              0
# OBSERVACION          0
# LATITUD              7
# LONGITUD             7
# MUNICIPIO            0
# dtype: int64

# %%
#Verificar el tipo de dato de AREA_Ha
print("Tipo de dato original de AREA_Ha :",df['AREA_Ha'].dtype)
# Out:
# Tipo de dato original de AREA_Ha : object

# %%
#Convertir a númenrico
df['AREA_Ha']=pd.to_numeric(df['AREA_Ha'],errors='coerce')
print("Tipo de dato después de convertir AREA_Ha :",df['AREA_Ha'].dtype)
# Out:
# Tipo de dato después de convertir AREA_Ha : float64

# %%
#Tipos de datos de cada columna
df.dtypes
# Out:
# ID                  int64
# TIPO GEOMETRIA     object
# AÑO                object
# IMAGEN             object
# CAUSA              object
# AREA_Ha           float64
# OBSERVACION        object
# LATITUD            object
# LONGITUD           object
# MUNICIPIO          object
# dtype: object

# %%
#Revisar si hubo valores no convertidos
n_no_numericos=df['AREA_Ha'].isna().sum()
print(f"Valores no númericos convertidos a NaN : {n_no_numericos}")
# Out:
# Valores no númericos convertidos a NaN : 0

# %%
#Eliminar filas donde una columna tenga valores nulos
df= df.dropna(subset=['AREA_Ha'])
print("Eliminar filas donde una columna tenga valores nulos : OK")
# Out:
# Eliminar filas donde una columna tenga valores nulos : OK

# %%
#Revisar si hubo valores no convertidos
n_no_numericos=df['AREA_Ha'].isna().sum()
print(f"Valores no númericos convertidos a NaN : {n_no_numericos}")
# Out:
# Valores no númericos convertidos a NaN : 0

# %% [markdown]
# ## 1. Distribución general
# Histograma para ver cómo se distribuyen las áreas deforestadas

# %%
import seaborn as sns
df['AREA_Ha'] = df['AREA_Ha'].astype(float)
#Crear histograma
plt.figure(figsize=(8,5))
sns.histplot(df['AREA_Ha'],bins=30,kde=True)
plt.title("Distribución del área deforestada (hectáreas)")
plt.xlabel('Área en hectáreas')
plt.ylabel("Número de zonas")
plt.show()

# %%
import seaborn as sns
#df['AREA_Ha'] = df['AREA_Ha'].astype(float)
df['AREA_HaF'] = df['AREA_Ha'].where((df['AREA_Ha']>=0) & (df['AREA_Ha']<=20))
#Crear histograma
plt.figure(figsize=(8,5))
sns.histplot(df['AREA_HaF'],bins=30,kde=True)
plt.title("Distribución del área deforestada (hectáreas)")
plt.xlabel('Área en hectáreas')
plt.ylabel("Número de zonas")
plt.show()

# %%
import seaborn as sns
#df['AREA_Ha'] = df['AREA_Ha'].astype(float)
df['AREA_HaF'] = df['AREA_Ha'].where((df['AREA_Ha']>=0) & (df['AREA_Ha']<=20))
#Crear histograma
plt.figure(figsize=(8,5))
sns.histplot(df['AREA_HaF'],
             bins=30,
             kde=True,
             palette="viridis",
             edgecolor="black"
             )
plt.title("Distribución del área deforestada (hectáreas)")
plt.xlabel('Área en hectáreas')
plt.ylabel("Número de zonas")
plt.show()
# Out:
# /tmp/ipython-input-2249156387.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['AREA_HaF'],

# %% [markdown]
# Interpretación:
# Las barras altas muestran los randos más comunes de áreas
#
# la línea suave muestra la forma general de la distribución

# %%
#Boxplot Diagrama de caja

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['AREA_Ha'])
plt.title("Boxplot del área deforestada ")
plt.xlabel("área en hectáreas")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['AREA_HaF'])
plt.title("Boxplot del área deforestada ")
plt.xlabel("área en hectáreas")
plt.show()

# %% [markdown]
# ## Evolución temporal
# Gráfico de barras de deforestación por año
#
# Permite cer cómo ha cambiado la deforestación entre 2015-20222

# %%
df['AÑO']=df['AÑO'].str.replace(',','').astype(int)
df.groupby('AÑO')['AREA_Ha'].sum().plot(kind='bar')
plt.title("Área deforestada por año")
plt.ylabel("Hectáreas")
plt.show()

# %%
# viridis, plasma, inferno, tab20, cool
data = df.groupby('AÑO')['AREA_Ha'].sum()
colors= plt.cm.viridis(np.linspace(0,1,len(data)))
data.plot(kind='bar',color=colors)
plt.title("Área deforestada por año")
plt.ylabel("Hectáreas")
plt.show()
print("len(data:",len(data))
print("np.linspace(0,1,len(data):",np.linspace(0,1,len(data)))
# Out:
# len(data: 8
# np.linspace(0,1,len(data): [0.         0.14285714 0.28571429 0.42857143 0.57142857 0.71428571
#  0.85714286 1.        ]

# %%
# Top 10 municipios con mayor área deforestada
df.groupby('MUNICIPIO')['AREA_Ha'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("Top 10 municipios con mayor área deforestada")
plt.ylabel("Área (Ha)")
plt.show()

# %%
df.head()
# Out:
#      ID TIPO GEOMETRIA   AÑO  \
# 0  7463        Polygon  2020
# 1  4659        Polygon  2019
# 2  7459        Polygon  2020
# 3  9719        Polygon  2021
# 4  7464        Polygon  2020
#
#                                               IMAGEN    CAUSA   AREA_Ha  \
# 0  T18PTQ_20200201T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.126512
# 1  T18PTQ_20190527T153621_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.140720
# 2  T18PTQ_20200112T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.141250
# 3  T18PTQ_20201202T153619_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.158066
# 4  T18PTQ_20200201T153611_TCI_10m.jp2 - T18PTQ_20...  Cultivo  0.184549
#
#   OBSERVACION           LATITUD           LONGITUD MUNICIPIO  AREA_HaF
# 0     Ninguna  8° 22' 43,726" N  77° 14' 19,019" W    ACANDÍ  0.126512
# 1     Ninguna  8° 30' 47,551" N  77° 19' 30,507" W    ACANDÍ  0.140720
# 2     Ninguna  8° 22' 30,966" N  77° 13' 49,720" W    ACANDÍ  0.141250
# 3     Ninguna  8° 36' 11.256" N  77° 20' 50.757" W    ACANDÍ  0.158066
# 4     Ninguna  8° 22' 22,008" N   77° 14' 3,921" W    ACANDÍ  0.184549

# %% [markdown]
# ## Convierte las  coordenadas Latitud y longitud a decimales

# %%
import re
def dms_a_decimal(coord):
    """
    Convierte coordenadas DMS (tipo '8° 30' 47,551" N' o '77° 14' 19,019" W') a decimal.
    Soporta formatos con comas o puntos decimales.
    Devuelve NaN si el formato no se reconoce.
    """
    if pd.isna(coord):
        return np.nan

    # Limpiar espacios y normalizar comillas
    coord = str(coord).strip().replace("″", '"').replace("’", "'").replace("”", '"')

    # Expresión regular mejorada
    match = re.match(
        r'(\d+)[°\s]+(\d+)?[\'\s]*(\d+[.,]?\d*)?"?\s*([NnSsEeOoWw])',
        coord
    )

    if not match:
        return np.nan

    grados = float(match.group(1))
    minutos = float(match.group(2)) if match.group(2) else 0
    segundos = float(str(match.group(3)).replace(',', '.')) if match.group(3) else 0
    direccion = match.group(4).upper()

    # Conversión a decimal
    decimal = grados + (minutos / 60) + (segundos / 3600)

    # Si es Sur (S), Oeste (O), o West (W), hacer negativo
    if direccion in ['S', 'O', 'W']:
        decimal *= -1

    return decimal

# %% [markdown]
# ## 🗺️ Mapa geográfico

# %%
# Aplicar la conversión a todo el DataFrame
df['LATITUD_DECIMAL']=df['LATITUD'].apply(dms_a_decimal)
df['LONGITUD_DECIMAL']=df['LONGITUD'].apply(dms_a_decimal)
# Revisar los primeros valores
df[['LATITUD','LATITUD_DECIMAL','LONGITUD','LONGITUD_DECIMAL']].head()
# Out:
#             LATITUD  LATITUD_DECIMAL           LONGITUD  LONGITUD_DECIMAL
# 0  8° 22' 43,726" N         8.378813  77° 14' 19,019" W        -77.238616
# 1  8° 30' 47,551" N         8.513209  77° 19' 30,507" W        -77.325141
# 2  8° 22' 30,966" N         8.375268  77° 13' 49,720" W        -77.230478
# 3  8° 36' 11.256" N         8.603127  77° 20' 50.757" W        -77.347432
# 4  8° 22' 22,008" N         8.372780   77° 14' 3,921" W        -77.234423

# %%
import folium
mapa = folium.Map(location=[5.7, -76.8],zoom_start=7)
for _, row in df.head(100).iterrows():
  folium.CircleMarker([row['LATITUD_DECIMAL'],row['LONGITUD_DECIMAL']],radius=2,color='red').add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c56708af3622a4c0eba691c649656fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c56708af3622a4c0eba691c649656fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c56708af3622a4c0eba691c649656fd = L.map(
#                 &quot;map_6c56708af3622a4c0eba691c649656fd&quot;,
#                 {
#                     center: [5.7, -76.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba0b3f9cfb102284dd7c33abd2d512c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba0b3f9cfb102284dd7c33abd2d512c3.addTo(map_6c56708af3622a4c0eba691c649656fd);
#
#
#             var circle_marker_886db3fdb89ef2c7787d5e0d32ba852d = L.circleMarker(
#                 [8.378812777777778, -77.23861638888889],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c56708af3622a4c0eba691c649656fd);
#
#
#             var circle_marker_761187a3d8edd68cdf49c313236bb7cb = L.circleMarker(
#                 [8.51320861111111, -77.32514083333334],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c56708af3622a4c0eba691c649656fd);
#
#
#             var circle_marker_46e8b04cf0fc90cb845c7e70801d701a = L.circleMarker(
#                 [8.375268333333334, -77.23047777777778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c56708af3622a4c0eba691c649656fd);
#
#
#             var circle_marker_e8b75919505af198ef737f658421a89e = L.circleMarker(
#                 [8.603126666666666, -77.3474325],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c56708af3622a4c0eba691c649656fd);
#
#
#             var circle_marker_6fd93309c85d36c9ee49dfa7211a5183 = L.circleMarker(
#                 [8.37278, -77.23442250000001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c56708af3622a4c0eba691c649656fd);
#
#
#             var circle_marker_5f594418e30e2966d88841a6df868e88 = L.circleMarker(
#                 [8.335357222222223, -77.21170027777778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quo

# %%
df.nlargest(20,'AREA_Ha')
# Out:
#         ID TIPO GEOMETRIA   AÑO  \
# 3640  5093        Polygon  2014
# 2665  1478        Polygon  2015
# 6782  2794        Polygon  2016
# 6781  2795        Polygon  2016
# 6780  2822        Polygon  2016
# 6779  2789        Polygon  2016
# 7936  5902        Polygon  2017
# 3728  5924        Polygon  2019
# 7787  2945        Polygon  2019
# 2474  5442        Polygon  2014
# 746   5063        Polygon  2015
# 4202  5020        Polygon  2016
# 7786  4814        Polygon  2019
# 745   5064        Polygon  2015
# 1428  1379        Polygon  2018
# 6778  2759        Polygon  2018
# 4201  5853        Polygon  2014
# 6777  2661        Polygon  2016
# 6776  2827        Polygon  2016
# 7935  5901        Polygon  2017
#
#                                                  IMAGEN        CAUSA  \
# 3640                                                NaN      Minería
# 2665                                                NaN  Desconocida
# 6782  LC80100552015082LGN00_b1b7.tif - LC80100552016...     Incendio
# 6781  LC80100552015082LGN00_b1b7.tif - LC80100552016...     Incendio
# 6780                                                NaN  Desconocida
# 6779  LC80100552016293LGN00_B4B6.tif - LC80100552016...      Cultivo
# 7936                                                NaN      Minería
# 3728                 T18NUL_20190522T153629_TCI_10m.jp2  Desconocida
# 7787  S2B_T18NTP_20190313T153619_TCI_10m.jp2 - S2B_T...     Incendio
# 2474                                                NaN      Minería
# 746                                                 NaN      Minería
# 4202  LC80100562015194LGN00_B4B5B6.tif - LC801005620...      Minería
# 7786  T18NTP_20190512T153629_TCI_10m.jp2 - T18NTP_20...     Incendio
# 745                                                 NaN      Minería
# 1428  LC08_L1TP_010056_20180110_B4B6.tif - LC08_L1TP...  Desconocida
# 6778  LC08_L1TP_010055_20181025_B4B6.tif - LC08_L1TP...     Incendio
# 4201                                                NaN      Minería
# 6777  lc80100552015_002_l1_6.tif - LC80100552016085L...      Cultivo
# 6776                                                NaN  Desconocida
# 7935                                                NaN      Minería
#
#          AREA_Ha OBSERVACION           LATITUD           LONGITUD  \
# 3640  785.882401     Ninguna    6° 3' 8,981" N  76° 35' 41,666" W
# 2665  713.636508     Ninguna   4° 3' 57,108" N  76° 51' 36,013" W
# 6782  703.896457     Ninguna  7° 32' 37,661" N  76° 57' 42,569" W
# 6781  677.570024     Ninguna  7° 31' 33,300" N  76° 56' 10,890" W
# 6780  448.914747     Ninguna   7° 31' 1,896" N  76° 59' 33,220" W
# 6779  416.754268     Ninguna  7° 39' 49,901" N  77° 19' 10,509" W
# 7936  358.591495     Ninguna   5° 17' 5,200" N  76° 39' 58,644" W
# 3728  353.077640     Ninguna   5° 3' 28,689" N  76° 44' 28,254" W
# 7787  339.601808     Ninguna  7° 58' 14,407" N   77° 5' 41,917" W
# 2474  293.995915     Ninguna   5° 23' 2,944" N  76° 44' 46,582" W
# 746   268.279556     Ninguna  5° 39' 43,716" N   76° 37' 2,381" W
# 4202  247.294688     Ninguna  4° 50' 35,571" N  76° 38' 20,019" W
# 7786  233.532467     Ninguna  7° 58' 33,835" N   77° 4' 40,255" W
# 745   220.835517     Ninguna  5° 38' 28,959" N   76° 35' 2,320" W
# 1428  217.986512     Ninguna  6° 27' 12,377" N   77° 1' 55,022" W
# 6778  212.455110     Ninguna   7° 12' 7,454" N   77° 6' 43,863" W
# 4201  210.952589     Ninguna  4° 53' 12,361" N  76° 38' 42,983" W
# 6777  204.418945     Ninguna  7° 21' 50,932" N  76° 59' 39,150" W
# 6776  197.973391     Ninguna  7° 18' 36,401" N   76° 50' 9,836" W
# 7935  196.039924     Ninguna  5° 17' 12,297" N  76° 40' 29,077" W
#
#                     MUNICIPIO  AREA_HaF  LATITUD_DECIMAL  LONGITUD_DECIMAL
# 3640             MEDIO ATRATO       NaN         6.052495        -76.594907
# 2665  EL LITORAL DEL SAN JUAN       NaN         4.065863        -76.860004
# 6782                 RIOSUCIO       NaN         7.543795        -76.961825
# 6781                 RIOSUCIO       NaN         7.525917        -76.936358
# 6780                 RIOSUCIO       NaN         7.517193        -76.992561
# 6779                 RIOSUCIO       NaN         7.663861        -77.319586
# 7936       UNIÓN PANAMERICANA       NaN         5.284778        -76.666290
# 3728           MEDIO SAN JUAN       NaN         5.057969        -76.741182
# 7787                   UNGUÍA       NaN         7.970669        -77.094977
# 2474  EL CANTON DEL SAN PABLO       NaN         5.384151        -76.746273
# 746                    ATRATO       NaN         5.662143        -76.617328
# 4202                   NÓVITA       NaN         4.843214        -76.638894
# 7786                   UNGUÍA       NaN         7.976065        -77.077849
# 745                    ATRATO       NaN         5.641377        -76.583978
# 1428                   BOJAYÁ       NaN         6.453438        -77.031951
# 6778                 RIOSUCIO       NaN         7.202071        -77.112184
# 4201                   NÓVITA       NaN         4.886767        -76.645273
# 6777                 RIOSUCIO       NaN         7.364148        -76.994208
# 6776                 RIOSUCIO       NaN         7.310111        -76.836066
# 7935       UNIÓN PANAMERICANA       NaN         5.286749        -76.674744

# %%
mapa = folium.Map(location=[5.7, -76.8],zoom_start=7)
for _, row in df.nlargest(10,'AREA_Ha').iterrows():
  folium.CircleMarker([row['LATITUD_DECIMAL'],row['LONGITUD_DECIMAL']],radius=2,color='red').add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67800c1b0cd7a138baae677a29668bbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67800c1b0cd7a138baae677a29668bbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67800c1b0cd7a138baae677a29668bbd = L.map(
#                 &quot;map_67800c1b0cd7a138baae677a29668bbd&quot;,
#                 {
#                     center: [5.7, -76.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f94135a7b628e01982fd05e0f29c0e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f94135a7b628e01982fd05e0f29c0e3.addTo(map_67800c1b0cd7a138baae677a29668bbd);
#
#
#             var circle_marker_74dd5c0ef740e5dfaaa23410c02d3488 = L.circleMarker(
#                 [6.052494722222222, -76.59490722222222],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67800c1b0cd7a138baae677a29668bbd);
#
#
#             var circle_marker_408361cd8297651bc5933442824f755e = L.circleMarker(
#                 [4.065863333333333, -76.86000361111111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67800c1b0cd7a138baae677a29668bbd);
#
#
#             var circle_marker_03ef52c3b025c06f4e32912d611b5a14 = L.circleMarker(
#                 [7.543794722222222, -76.96182472222222],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67800c1b0cd7a138baae677a29668bbd);
#
#
#             var circle_marker_f814aa5c2edcff9482c6fa1363a0af64 = L.circleMarker(
#                 [7.525916666666666, -76.93635833333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67800c1b0cd7a138baae677a29668bbd);
#
#
#             var circle_marker_0c460abfd7e88e706a3fb3f36986895e = L.circleMarker(
#                 [7.517193333333333, -76.99256111111112],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_67800c1b0cd7a138baae677a29668bbd);
#
#
#             var circle_marker_2ba16f3dd68734ab9fc1af095d6213d5 = L.circleMarker(
#                 [7.663861388888889, -77.31958583333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7928 entries, 0 to 7936
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                7928 non-null   int64
#  1   TIPO GEOMETRIA    7928 non-null   object
#  2   AÑO               7928 non-null   int64
#  3   IMAGEN            5893 non-null   object
#  4   CAUSA             7709 non-null   object
#  5   AREA_Ha           7928 non-null   float64
#  6   OBSERVACION       7928 non-null   object
#  7   LATITUD           7921 non-null   object
#  8   LONGITUD          7921 non-null   object
#  9   MUNICIPIO         7928 non-null   object
#  10  AREA_HaF          7604 non-null   float64
#  11  LATITUD_DECIMAL   7921 non-null   float64
#  12  LONGITUD_DECIMAL  7921 non-null   float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 867.1+ KB
